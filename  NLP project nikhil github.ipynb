# %%
import numpy as np
import seaborn as sns

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# %%
import matplotlib.pyplot as plt
from matplotlib import image
from PIL import Image

# %%
# !unzip '/content/drive/MyDrive/txt_reviews.zip'  -d '/content/sample_data/Project'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/sample_data/Project/txt_reviews/review_95499.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_955.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9550.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95500.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95501.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95502.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95503.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95504.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95505.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95506.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95507.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95508.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95509.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9551.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95510.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95511.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95512.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95513.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95514.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95515.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95516.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95517.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95518.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95519.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9552.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95520.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95521.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95522.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95523.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95524.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95525.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95526.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95527.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95528.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95529.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9553.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95530.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95531.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95532.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95533.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95534.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95535.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95536.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95537.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95538.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95539.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9554.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95540.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95541.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95542.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95543.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95544.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95545.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95546.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95547.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95548.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95549.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9555.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95550.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95551.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95552.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95553.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95554.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95555.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95556.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95557.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95558.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95559.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9556.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95560.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95561.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95562.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95563.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95564.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95565.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95566.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95567.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95568.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95569.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9557.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95570.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95571.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95572.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95573.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95574.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95575.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95576.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95577.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95578.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95579.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9558.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95580.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95581.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95582.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95583.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95584.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95585.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95586.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95587.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95588.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95589.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9559.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95590.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95591.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95592.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95593.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95594.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95595.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95596.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95597.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95598.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95599.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_956.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9560.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95600.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95601.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95602.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95603.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95604.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95605.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95606.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95607.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95608.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95609.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9561.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95610.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95611.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95612.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95613.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95614.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95615.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95616.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95617.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95618.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95619.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9562.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95620.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95621.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95622.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95623.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95624.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95625.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95626.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95627.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95628.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95629.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9563.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95630.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95631.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95632.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95633.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95634.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95635.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95636.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95637.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95638.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95639.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9564.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95640.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95641.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95642.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95643.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95644.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95645.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95646.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95647.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95648.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95649.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9565.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95650.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95651.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95652.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95653.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95654.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95655.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95656.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95657.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95658.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95659.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9566.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95660.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95661.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95662.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95663.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95664.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95665.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95666.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95667.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95668.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95669.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9567.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95670.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95671.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95672.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95673.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95674.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95675.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95676.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95677.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95678.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95679.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9568.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95680.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95681.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95682.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95683.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95684.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95685.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95686.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95687.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95688.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95689.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9569.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95690.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95691.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95692.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95693.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95694.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95695.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95696.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95697.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95698.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95699.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_957.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9570.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95700.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95701.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95702.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95703.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95704.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95705.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95706.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95707.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95708.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95709.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9571.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95710.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95711.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95712.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95713.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95714.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95715.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95716.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95717.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95718.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95719.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9572.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95720.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95721.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95722.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95723.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95724.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95725.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95726.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95727.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95728.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95729.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9573.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95730.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95731.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95732.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95733.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95734.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95735.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95736.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95737.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95738.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95739.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9574.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95740.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95741.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95742.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95743.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95744.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95745.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95746.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95747.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95748.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95749.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9575.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95750.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95751.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95752.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95753.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95754.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95755.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95756.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95757.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95758.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95759.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9576.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95760.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95761.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95762.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95763.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95764.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95765.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95766.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95767.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95768.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95769.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9577.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95770.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95771.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95772.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95773.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95774.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95775.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95776.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95777.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95778.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95779.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9578.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95780.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95781.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95782.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95783.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95784.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95785.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95786.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95787.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95788.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95789.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9579.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95790.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95791.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95792.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95793.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95794.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95795.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95796.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95797.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95798.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95799.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_958.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9580.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95800.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95801.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95802.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95803.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95804.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95805.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95806.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95807.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95808.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95809.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9581.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95810.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95811.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95812.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95813.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95814.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95815.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95816.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95817.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95818.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95819.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9582.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95820.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95821.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95822.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95823.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95824.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95825.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95826.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95827.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95828.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95829.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9583.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95830.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95831.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95832.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95833.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95834.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95835.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95836.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95837.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95838.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95839.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9584.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95840.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95841.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95842.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95843.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95844.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95845.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95846.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95847.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95848.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95849.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9585.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95850.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95851.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95852.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95853.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95854.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95855.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95856.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95857.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95858.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95859.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9586.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95860.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95861.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95862.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95863.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95864.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95865.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95866.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95867.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95868.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95869.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9587.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95870.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95871.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95872.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95873.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95874.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95875.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95876.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95877.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95878.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95879.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9588.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95880.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95881.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95882.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95883.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95884.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95885.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95886.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95887.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95888.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95889.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9589.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95890.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95891.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95892.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95893.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95894.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95895.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95896.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95897.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95898.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95899.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_959.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9590.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95900.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95901.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95902.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95903.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95904.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95905.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95906.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95907.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95908.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95909.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9591.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95910.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95911.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95912.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95913.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95914.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95915.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95916.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95917.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95918.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95919.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9592.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95920.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95921.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95922.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95923.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95924.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95925.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95926.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95927.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95928.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95929.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9593.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95930.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95931.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95932.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95933.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95934.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95935.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95936.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95937.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95938.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95939.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9594.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95940.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95941.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95942.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95943.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95944.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95945.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95946.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95947.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95948.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95949.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9595.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95950.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95951.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95952.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95953.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95954.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95955.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95956.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95957.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95958.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95959.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9596.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95960.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95961.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95962.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95963.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95964.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95965.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95966.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95967.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95968.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95969.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9597.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95970.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95971.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95972.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95973.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95974.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95975.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95976.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95977.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95978.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95979.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9598.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95980.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95981.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95982.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95983.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95984.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95985.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95986.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95987.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95988.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95989.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9599.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95990.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95991.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95992.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95993.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95994.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95995.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95996.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95997.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95998.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_95999.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_960.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9600.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96000.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96001.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96002.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96003.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96004.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96005.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96006.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96007.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96008.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96009.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9601.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96010.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96011.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96012.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96013.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96014.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96015.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96016.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96017.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96018.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96019.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9602.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96020.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96021.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96022.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96023.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96024.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96025.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96026.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96027.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96028.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96029.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9603.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96030.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96031.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96032.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96033.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96034.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96035.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96036.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96037.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96038.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96039.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9604.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96040.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96041.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96042.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96043.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96044.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96045.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96046.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96047.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96048.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96049.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9605.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96050.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96051.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96052.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96053.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96054.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96055.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96056.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96057.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96058.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96059.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9606.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96060.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96061.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96062.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96063.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96064.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96065.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96066.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96067.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96068.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96069.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9607.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96070.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96071.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96072.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96073.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96074.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96075.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96076.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96077.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96078.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96079.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9608.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96080.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96081.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96082.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96083.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96084.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96085.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96086.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96087.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96088.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_96089.txt
# ...
#   inflating: /content/sample_data/Project/txt_reviews/review_99801.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99802.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99803.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99804.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99805.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99806.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99807.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99808.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99809.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9981.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99810.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99811.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99812.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99813.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99814.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99815.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99816.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99817.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99818.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99819.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9982.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99820.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99821.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99822.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99823.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99824.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99825.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99826.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99827.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99828.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99829.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9983.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99830.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99831.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99832.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99833.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99834.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99835.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99836.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99837.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99838.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99839.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9984.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99840.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99841.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99842.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99843.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99844.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99845.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99846.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99847.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99848.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99849.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9985.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99850.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99851.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99852.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99853.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99854.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99855.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99856.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99857.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99858.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99859.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9986.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99860.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99861.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99862.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99863.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99864.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99865.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99866.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99867.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99868.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99869.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9987.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99870.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99871.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99872.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99873.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99874.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99875.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99876.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99877.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99878.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99879.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9988.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99880.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99881.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99882.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99883.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99884.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99885.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99886.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99887.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99888.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99889.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9989.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99890.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99891.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99892.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99893.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99894.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99895.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99896.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99897.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99898.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99899.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_999.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9990.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99900.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99901.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99902.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99903.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99904.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99905.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99906.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99907.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99908.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99909.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9991.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99910.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99911.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99912.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99913.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99914.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99915.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99916.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99917.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99918.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99919.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9992.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99920.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99921.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99922.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99923.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99924.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99925.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99926.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99927.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99928.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99929.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9993.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99930.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99931.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99932.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99933.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99934.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99935.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99936.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99937.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99938.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99939.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9994.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99940.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99941.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99942.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99943.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99944.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99945.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99946.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99947.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99948.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99949.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9995.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99950.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99951.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99952.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99953.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99954.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99955.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99956.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99957.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99958.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99959.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9996.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99960.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99961.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99962.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99963.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99964.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99965.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99966.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99967.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99968.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99969.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9997.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99970.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99971.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99972.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99973.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99974.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99975.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99976.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99977.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99978.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99979.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9998.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99980.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99981.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99982.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99983.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99984.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99985.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99986.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99987.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99988.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99989.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_9999.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99990.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99991.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99992.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99993.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99994.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99995.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99996.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99997.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99998.txt
#   inflating: /content/sample_data/Project/txt_reviews/review_99999.txt

# %%
import os
import pandas as pd
import numpy as np

# %%
file_names=os.listdir('/content/sample_data/Project/txt_reviews')
print(len(file_names))
# Out:
# 568454

# %%
ProductId =[]
UserId =[]
ProfileName=[]
HelpfulnessNumerator =[]
HelpfulnessDenominator =[]
Score =[]
Time =[]
ReviewSummary=[]
ReviewText=[]
for i in file_names:
  with open('/content/sample_data/Project/txt_reviews/'+i, 'r') as f:
        lines = f.readlines()
        ProductId.append(lines[0])
        UserId.append(lines[1])
        ProfileName.append(lines[2])
        HelpfulnessNumerator.append(lines[3])
        HelpfulnessDenominator.append(lines[4])
        Score.append(lines[5])
        Time.append(lines[6])
        ReviewSummary.append(lines[7])
        ReviewText.append(lines[8])
        
df = pd.DataFrame({'ProductId':ProductId,'UserId':UserId,'ProfileName':ProfileName,'HelpfulnessNumerator':HelpfulnessNumerator,
                   'HelpfulnessDenominator':HelpfulnessDenominator,'Score':Score,'Time':Time,'ReviewSummary':ReviewSummary,
                   'ReviewText':ReviewText})

# %%
df
# Out:
#                       ProductId                    UserId  \
# 0       ProductId: B00066CRXG\n   UserId: AR0V0VAFUSP7Q\n
# 1       ProductId: B000VDBJ10\n  UserId: A2MFN0JN3D2KUU\n
# 2       ProductId: B000CMDRWO\n   UserId: AMQWTIIHWRZFR\n
# 3       ProductId: B002GWHC0G\n  UserId: A2EFAW1P3DRXWO\n
# 4       ProductId: B006ACQYXY\n  UserId: A36SOVNTDS3VC6\n
# ...                         ...                       ...
# 568449  ProductId: B0000D9541\n   UserId: AL541XC7589P6\n
# 568450  ProductId: B0000DCX0P\n  UserId: A281NPSIMI1C2R\n
# 568451  ProductId: B000VMBE8E\n  UserId: A12Q5LN4DUTDHT\n
# 568452  ProductId: B003K2NH4Q\n  UserId: A22H1FPB0E66YZ\n
# 568453  ProductId: B000NCVKG8\n   UserId: ACNF5NXE7H8BJ\n
#
#                                               ProfileName  \
# 0                       ProfileName: Cassie T. Oconnell\n
# 1                         ProfileName: Kimberly Elliott\n
# 2                            ProfileName: Mary E. Clyde\n
# 3                               ProfileName: TJ Fairfax\n
# 4                          ProfileName: Bobbie Bradshaw\n
# ...                                                   ...
# 568449         ProfileName: James R. Michaels "Sr. Rav"\n
# 568450  ProfileName: Rebecca of Amazon "The Rebecca Re...
# 568451                            ProfileName: Bluebird\n
# 568452                   ProfileName: Mavon Chante Cole\n
# 568453                                ProfileName: AJBJ\n
#
#              HelpfulnessNumerator       HelpfulnessDenominator       Score  \
# 0       HelpfulnessNumerator: 1\n  HelpfulnessDenominator: 1\n  Score: 5\n
# 1       HelpfulnessNumerator: 2\n  HelpfulnessDenominator: 2\n  Score: 5\n
# 2       HelpfulnessNumerator: 0\n  HelpfulnessDenominator: 0\n  Score: 5\n
# 3       HelpfulnessNumerator: 0\n  HelpfulnessDenominator: 0\n  Score: 5\n
# 4       HelpfulnessNumerator: 1\n  HelpfulnessDenominator: 1\n  Score: 5\n
# ...                           ...                          ...         ...
# 568449  HelpfulnessNumerator: 0\n  HelpfulnessDenominator: 0\n  Score: 5\n
# 568450  HelpfulnessNumerator: 1\n  HelpfulnessDenominator: 1\n  Score: 5\n
# 568451  HelpfulnessNumerator: 3\n  HelpfulnessDenominator: 3\n  Score: 5\n
# 568452  HelpfulnessNumerator: 4\n  HelpfulnessDenominator: 4\n  Score: 5\n
# 568453  HelpfulnessNumerator: 0\n  HelpfulnessDenominator: 0\n  Score: 5\n
#
#                       Time                                      ReviewSummary  \
# 0       Time: 1168300800\n                   ReviewSummary: TOP OF THE LINE\n
# 1       Time: 1200614400\n                     ReviewSummary: Great Beans!!\n
# 2       Time: 1217462400\n                 ReviewSummary: Unsalted Soy nuts\n
# 3       Time: 1349395200\n               ReviewSummary: Our guests love it!\n
# 4       Time: 1322179200\n           ReviewSummary: I really like this salt\n
# ...                    ...                                                ...
# 568449  Time: 1286236800\n                      ReviewSummary: A sweet deal\n
# 568450  Time: 1168732800\n            ReviewSummary: Make Your Own Chai Tea\n
# 568451  Time: 1300406400\n                              ReviewSummary: YUM!\n
# 568452  Time: 1337904000\n  ReviewSummary: it's great for natural black ha...
# 568453  Time: 1325635200\n                    ReviewSummary: Good and yummy\n
#
#                                                ReviewText
# 0       ReviewText: THIS IS AN EXCELLENT PRODUCT AND A...
# 1       ReviewText: These vanilla beans were moist, ar...
# 2       ReviewText: This product tasted good and was a...
# 3       ReviewText: We roast these in a large cast iro...
# 4       ReviewText: I had sampled some Himalayan Sea S...
# ...                                                   ...
# 568449  ReviewText: This candy is very tasty. If you w...
# 568450  ReviewText: Cardamom-an ancient spice native t...
# 568451  ReviewText: These are wonderfully delicious......
# 568452  ReviewText: I had read in an article about mus...
# 568453  ReviewText: These sprouted well and were ready...
#
# [568454 rows x 9 columns]

# %%
df.to_csv('review_data')

# %%
df_data=pd.read_csv('/content/drive/MyDrive/review_data')

# %%
df_data
# Out:
#         Unnamed: 0                ProductId                    UserId  \
# 0                0  ProductId: B001E7653Y\n  UserId: A1B05INWIDZ74O\n
# 1                1  ProductId: B003E728CE\n  UserId: A2JGG7FAJP1JYI\n
# 2                2  ProductId: B007TJGZ4A\n  UserId: A37EAY838W4NIJ\n
# 3                3  ProductId: B000EMD1N2\n  UserId: A1LN46HVNO2F0Q\n
# 4                4  ProductId: B001LFEUCM\n   UserId: AX2NFBR9JZI6M\n
# ...            ...                      ...                       ...
# 568449      568449  ProductId: B00570T1W6\n  UserId: A2P3HZZDI9QKZN\n
# 568450      568450  ProductId: B000F3WSBQ\n   UserId: AEG38F1IZJZ2X\n
# 568451      568451  ProductId: B004L321C2\n  UserId: A2A68P2F8JRI83\n
# 568452      568452  ProductId: B006ACQYB6\n   UserId: ASB872LI0LBKT\n
# 568453      568453  ProductId: B003DGWB78\n  UserId: A2RZT9Z9LM7S4Z\n
#
#                                        ProfileName       HelpfulnessNumerator  \
# 0                       ProfileName: M. A. Ramos\n  HelpfulnessNumerator: 2\n
# 1                         ProfileName: P. Summer\n  HelpfulnessNumerator: 0\n
# 2       ProfileName: Adrienne Soule "Minx_in_La"\n  HelpfulnessNumerator: 1\n
# 3             ProfileName: Michael S. Montgomery\n  HelpfulnessNumerator: 0\n
# 4                   ProfileName: Rebekah Dassion\n  HelpfulnessNumerator: 5\n
# ...                                            ...                        ...
# 568449  ProfileName: Jane Doeberg "Jane Doeberg"\n  HelpfulnessNumerator: 0\n
# 568450               ProfileName: Erik W. Arness\n  HelpfulnessNumerator: 2\n
# 568451    ProfileName: 1.withall "Miracle Momma"\n  HelpfulnessNumerator: 0\n
# 568452                  ProfileName: maura derey\n  HelpfulnessNumerator: 0\n
# 568453                ProfileName: Monkeysfather\n  HelpfulnessNumerator: 0\n
#
#              HelpfulnessDenominator       Score                Time  \
# 0       HelpfulnessDenominator: 3\n  Score: 4\n  Time: 1210896000\n
# 1       HelpfulnessDenominator: 0\n  Score: 5\n  Time: 1260230400\n
# 2       HelpfulnessDenominator: 1\n  Score: 5\n  Time: 1267660800\n
# 3       HelpfulnessDenominator: 0\n  Score: 4\n  Time: 1315785600\n
# 4       HelpfulnessDenominator: 8\n  Score: 1\n  Time: 1201132800\n
# ...                             ...         ...                 ...
# 568449  HelpfulnessDenominator: 0\n  Score: 5\n  Time: 1330732800\n
# 568450  HelpfulnessDenominator: 2\n  Score: 5\n  Time: 1207353600\n
# 568451  HelpfulnessDenominator: 0\n  Score: 4\n  Time: 1343779200\n
# 568452  HelpfulnessDenominator: 0\n  Score: 5\n  Time: 1345680000\n
# 568453  HelpfulnessDenominator: 0\n  Score: 5\n  Time: 1347667200\n
#
#                                             ReviewSummary  \
# 0                          ReviewSummary: Great Tasting\n
# 1                         ReviewSummary: Unbelieveable!\n
# 2         ReviewSummary: Nice flavor and good packaging\n
# 3                              ReviewSummary: On the Go\n
# 4                                   ReviewSummary: Ick.\n
# ...                                                   ...
# 568449  ReviewSummary: Good alternative to higher calo...
# 568450          ReviewSummary: Great Service, Great Tea\n
# 568451  ReviewSummary: Great product...close to S'bux ...
# 568452                ReviewSummary: HIMALAYAN SEA SALT\n
# 568453                 ReviewSummary: Ghost Pepper salt\n
#
#                                                ReviewText
# 0       ReviewText: Since this seems to be a main conc...
# 1       ReviewText: I couldn't get my dog to take her ...
# 2       ReviewText: I appreciate that Gloria Jeans is ...
# 3       ReviewText: I bought this on special, thought ...
# 4       ReviewText: This is my very first review - I t...
# ...                                                   ...
# 568449  ReviewText: Saw these chips on Dr. Oz as an al...
# 568450  ReviewText: Yes , Amazon really does try to pr...
# 568451  ReviewText: Lovely coffee.  Smooth, not too ji...
# 568452  ReviewText: The Spice Lab is a completely wond...
# 568453  ReviewText: Fresh taste with the flavor of the...
#
# [568454 rows x 10 columns]

# %%
df_data.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df_data.head()
# Out:
#                  ProductId                    UserId  \
# 0  ProductId: B001E7653Y\n  UserId: A1B05INWIDZ74O\n
# 1  ProductId: B003E728CE\n  UserId: A2JGG7FAJP1JYI\n
# 2  ProductId: B007TJGZ4A\n  UserId: A37EAY838W4NIJ\n
# 3  ProductId: B000EMD1N2\n  UserId: A1LN46HVNO2F0Q\n
# 4  ProductId: B001LFEUCM\n   UserId: AX2NFBR9JZI6M\n
#
#                                   ProfileName       HelpfulnessNumerator  \
# 0                  ProfileName: M. A. Ramos\n  HelpfulnessNumerator: 2\n
# 1                    ProfileName: P. Summer\n  HelpfulnessNumerator: 0\n
# 2  ProfileName: Adrienne Soule "Minx_in_La"\n  HelpfulnessNumerator: 1\n
# 3        ProfileName: Michael S. Montgomery\n  HelpfulnessNumerator: 0\n
# 4              ProfileName: Rebekah Dassion\n  HelpfulnessNumerator: 5\n
#
#         HelpfulnessDenominator       Score                Time  \
# 0  HelpfulnessDenominator: 3\n  Score: 4\n  Time: 1210896000\n
# 1  HelpfulnessDenominator: 0\n  Score: 5\n  Time: 1260230400\n
# 2  HelpfulnessDenominator: 1\n  Score: 5\n  Time: 1267660800\n
# 3  HelpfulnessDenominator: 0\n  Score: 4\n  Time: 1315785600\n
# 4  HelpfulnessDenominator: 8\n  Score: 1\n  Time: 1201132800\n
#
#                                      ReviewSummary  \
# 0                   ReviewSummary: Great Tasting\n
# 1                  ReviewSummary: Unbelieveable!\n
# 2  ReviewSummary: Nice flavor and good packaging\n
# 3                       ReviewSummary: On the Go\n
# 4                            ReviewSummary: Ick.\n
#
#                                           ReviewText
# 0  ReviewText: Since this seems to be a main conc...
# 1  ReviewText: I couldn't get my dog to take her ...
# 2  ReviewText: I appreciate that Gloria Jeans is ...
# 3  ReviewText: I bought this on special, thought ...
# 4  ReviewText: This is my very first review - I t...

# %%
df_data.describe()
# Out:
#                       ProductId                    UserId  \
# count                    568454                    568454
# unique                    74258                    256059
# top     ProductId: B007JFMH8M\n  UserId: A3OXHLG6DIBRW8\n
# freq                        913                       448
#
#                             ProfileName       HelpfulnessNumerator  \
# count                            568454                     568454
# unique                           218417                        231
# top     ProfileName: C. F. Hill "CFH"\n  HelpfulnessNumerator: 0\n
# freq                                451                     303826
#
#              HelpfulnessDenominator       Score                Time  \
# count                        568454      568454              568454
# unique                          234           5                3168
# top     HelpfulnessDenominator: 0\n  Score: 5\n  Time: 1350345600\n
# freq                         270052      363122                1143
#
#                       ReviewSummary  \
# count                        568454
# unique                       295743
# top     ReviewSummary: Delicious!\n
# freq                           2462
#
#                                                ReviewText
# count                                              568454
# unique                                             393579
# top     ReviewText: This review will make me sound rea...
# freq                                                  199

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568454 entries, 0 to 568453
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   ProductId               568454 non-null  object
#  1   UserId                  568454 non-null  object
#  2   ProfileName             568454 non-null  object
#  3   HelpfulnessNumerator    568454 non-null  object
#  4   HelpfulnessDenominator  568454 non-null  object
#  5   Score                   568454 non-null  object
#  6   Time                    568454 non-null  object
#  7   ReviewSummary           568454 non-null  object
#  8   ReviewText              568454 non-null  object
# dtypes: object(9)
# memory usage: 39.0+ MB

# %%
df_data.isnull().sum()
# Out:
# ProductId                 0
# UserId                    0
# ProfileName               0
# HelpfulnessNumerator      0
# HelpfulnessDenominator    0
# Score                     0
# Time                      0
# ReviewSummary             0
# ReviewText                0
# dtype: int64

# %%
# cleaning Data

# %%
df_data['ProductId']=df_data['ProductId'].apply(lambda x:x.strip('ProductId:'))
df_data['ProductId']=df_data['ProductId'].apply(lambda x:x.strip('\n'))
df_data['UserId']=df_data['UserId'].apply(lambda x:x.strip('UserId:'))
df_data['UserId']=df_data['UserId'].apply(lambda x:x.strip('\n'))

df_data['ProfileName']=df_data['ProfileName'].apply(lambda x:x.strip('ProfileName:'))
df_data['ProfileName']=df_data['ProfileName'].apply(lambda x:x.strip('\n'))

df_data['HelpfulnessNumerator']=df_data['HelpfulnessNumerator'].apply(lambda x:x.strip('HelpfulnessNumerator:'))
df_data['HelpfulnessNumerator']=df_data['HelpfulnessNumerator'].apply(lambda x:x.strip('\n'))


df_data['HelpfulnessDenominator']=df_data['HelpfulnessDenominator'].apply(lambda x:x.strip('HelpfulnessDenominator:'))
df_data['HelpfulnessDenominator']=df_data['HelpfulnessDenominator'].apply(lambda x:x.strip('\n'))

df_data['Score']=df_data['Score'].apply(lambda x:x.strip('Score:'))
df_data['Score']=df_data['Score'].apply(lambda x:x.strip('\n'))

df_data['Time']=df_data['Time'].apply(lambda x:x.strip('Time:'))
df_data['Time']=df_data['Time'].apply(lambda x:x.strip('\n'))

df_data['ReviewSummary']=df_data['ReviewSummary'].apply(lambda x:x.strip('ReviewSummary:'))
df_data['ReviewSummary']=df_data['ReviewSummary'].apply(lambda x:x.strip('\n'))

df_data['ReviewText']=df_data['ReviewText'].apply(lambda x:x.strip('ReviewSummary:'))
df_data['ReviewText']=df_data['ReviewText'].apply(lambda x:x.strip('\n'))

# %%
df_data.duplicated().sum()
# Out:
# 0

# %%
df_data.drop_duplicates(inplace=True)

# %%
df_data.duplicated().sum()
# Out:
# 0

# %%
df_data.head()
# Out:
#    Unnamed: 0    ProductId           UserId                   ProfileName  \
# 0           0   B001E7653Y   A1B05INWIDZ74O                   M. A. Ramos
# 1           1   B003E728CE   A2JGG7FAJP1JYI                     P. Summer
# 2           2   B007TJGZ4A   A37EAY838W4NIJ   Adrienne Soule "Minx_in_La"
# 3           3   B000EMD1N2   A1LN46HVNO2F0Q         Michael S. Montgomery
# 4           4   B001LFEUCM    AX2NFBR9JZI6M               Rebekah Dassion
#
#   HelpfulnessNumerator HelpfulnessDenominator Score         Time  \
# 0                    2                      3     4   1210896000
# 1                    0                      0     5   1260230400
# 2                    1                      1     5   1267660800
# 3                    0                      0     4   1315785600
# 4                    5                      8     1   1201132800
#
#                      ReviewSummary  \
# 0                    Great Tasting
# 1                   Unbelieveable!
# 2   Nice flavor and good packaging
# 3                        On the Go
# 4                             Ick.
#
#                                           ReviewText
# 0  Text: Since this seems to be a main concern, I...
# 1  Text: I couldn't get my dog to take her incont...
# 2  Text: I appreciate that Gloria Jeans is availa...
# 3  Text: I bought this on special, thought it wou...
# 4  Text: This is my very first review - I thought...

# %% [markdown]
# # Type Conversion

# %%
df_data['HelpfulnessNumerator']=df_data['HelpfulnessNumerator'].astype(int)

# %%
df_data['HelpfulnessDenominator']=df_data['HelpfulnessDenominator'].astype(int)

# %%
df_data['Score']=df_data['Score'].astype(int)

# %%
df_data['Helpfulness']=df_data['HelpfulnessNumerator']/df_data['HelpfulnessDenominator']*100
df_data['Helpfulness']=df_data['Helpfulness'].fillna(0)

# %%
df_data['Helpfulness']=df_data['Helpfulness'].astype(int)

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 568173 entries, 0 to 568453
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   ProductId               568173 non-null  object
#  1   UserId                  568173 non-null  object
#  2   ProfileName             568173 non-null  object
#  3   HelpfulnessNumerator    568173 non-null  int64
#  4   HelpfulnessDenominator  568173 non-null  int64
#  5   Score                   568173 non-null  int64
#  6   Time                    568173 non-null  object
#  7   ReviewSummary           568173 non-null  object
#  8   ReviewText              568173 non-null  object
#  9   Helpfulness             568173 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 47.7+ MB

# %% [markdown]
# # Dropping unwanted Columns

# %%
df_data.drop('ProductId',axis=1,inplace=True)
df_data.drop('ProfileName',axis=1,inplace=True)
#df_data.drop('Score',axis=1,inplace=True)
#df_data.drop('Time',axis=1,inplace=True)
df_data.drop('HelpfulnessNumerator',axis=1,inplace=True)
df_data.drop('HelpfulnessDenominator',axis=1,inplace=True)
df_data.drop('UserId',axis=1,inplace=True)

# %%
df_data.head()
# Out:
#    Score         Time                    ReviewSummary  \
# 0      4   1210896000                    Great Tasting
# 1      5   1260230400                   Unbelieveable!
# 2      5   1267660800   Nice flavor and good packaging
# 3      4   1315785600                        On the Go
# 4      1   1201132800                             Ick.
#
#                                           ReviewText  Helpfulness
# 0  Text: Since this seems to be a main concern, I...           66
# 1  Text: I couldn't get my dog to take her incont...            0
# 2  Text: I appreciate that Gloria Jeans is availa...          100
# 3  Text: I bought this on special, thought it wou...            0
# 4  Text: This is my very first review - I thought...           62

# %%
df_data.to_csv('Cleaned_Data1')

# %%
df_data1=pd.read_csv('/content/drive/MyDrive/Cleaned_Data1')

# %%
df_data1.head()
# Out:
#    Unnamed: 0  Score        Time                    ReviewSummary  \
# 0           0      4  1210896000                    Great Tasting
# 1           1      5  1260230400                   Unbelieveable!
# 2           2      5  1267660800   Nice flavor and good packaging
# 3           3      4  1315785600                        On the Go
# 4           4      1  1201132800                             Ick.
#
#                                           ReviewText  Helpfulness
# 0  Text: Since this seems to be a main concern, I...           66
# 1  Text: I couldn't get my dog to take her incont...            0
# 2  Text: I appreciate that Gloria Jeans is availa...          100
# 3  Text: I bought this on special, thought it wou...            0
# 4  Text: This is my very first review - I thought...           62

# %%
df_data1.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df_data1.head()
# Out:
#    Score        Time                    ReviewSummary  \
# 0      4  1210896000                    Great Tasting
# 1      5  1260230400                   Unbelieveable!
# 2      5  1267660800   Nice flavor and good packaging
# 3      4  1315785600                        On the Go
# 4      1  1201132800                             Ick.
#
#                                           ReviewText  Helpfulness
# 0  Text: Since this seems to be a main concern, I...           66
# 1  Text: I couldn't get my dog to take her incont...            0
# 2  Text: I appreciate that Gloria Jeans is availa...          100
# 3  Text: I bought this on special, thought it wou...            0
# 4  Text: This is my very first review - I thought...           62

# %%
df_data1['Time'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 568173 entries, 0 to 568172
# Series name: Time
# Non-Null Count   Dtype
# --------------   -----
# 568173 non-null  int64
# dtypes: int64(1)
# memory usage: 4.3 MB

# %%
df_data1.head()
# Out:
#    Score        Time                    ReviewSummary  \
# 0      4  1210896000                    Great Tasting
# 1      5  1260230400                   Unbelieveable!
# 2      5  1267660800   Nice flavor and good packaging
# 3      4  1315785600                        On the Go
# 4      1  1201132800                             Ick.
#
#                                           ReviewText  Helpfulness
# 0  Text: Since this seems to be a main concern, I...           66
# 1  Text: I couldn't get my dog to take her incont...            0
# 2  Text: I appreciate that Gloria Jeans is availa...          100
# 3  Text: I bought this on special, thought it wou...            0
# 4  Text: This is my very first review - I thought...           62

# %%
import datetime
from datetime import datetime
import re

# %%
df_data1['Time']=df_data1['Time'].astype('int')
df_data1['Time'] = df_data1['Time'].apply(lambda x: datetime.fromtimestamp(x).isoformat())

df_data1['Time'] = df_data1['Time'].apply(lambda x: ''.join(re.findall('(.*)T',x)))

df_data1['Time'] = pd.to_datetime(df_data1['Time'])

# %%
df_data1['Helpfulness'].value_counts()
# Out:
# 0      303600
# 100    183271
# 50      21623
# 66      10514
# 75       6390
#         ...
# 24          7
# 150         1
# 1           1
# 49          1
# 300         1
# Name: Helpfulness, Length: 103, dtype: int64

# %%
df_data1.head()
# Out:
#    Score       Time                    ReviewSummary  \
# 0      4 2008-05-16                    Great Tasting
# 1      5 2009-12-08                   Unbelieveable!
# 2      5 2010-03-04   Nice flavor and good packaging
# 3      4 2011-09-12                        On the Go
# 4      1 2008-01-24                             Ick.
#
#                                           ReviewText  Helpfulness
# 0  Text: Since this seems to be a main concern, I...           66
# 1  Text: I couldn't get my dog to take her incont...            0
# 2  Text: I appreciate that Gloria Jeans is availa...          100
# 3  Text: I bought this on special, thought it wou...            0
# 4  Text: This is my very first review - I thought...           62

# %%
df_data1.loc[df_data1['Score']<3, 'Score'] = 0
df_data1.loc[df_data1['Score']>3, 'Score'] = 1

# %%
df_data1.head()
# Out:
#    Score       Time                    ReviewSummary  \
# 0      1 2008-05-16                    Great Tasting
# 1      1 2009-12-08                   Unbelieveable!
# 2      1 2010-03-04   Nice flavor and good packaging
# 3      1 2011-09-12                        On the Go
# 4      0 2008-01-24                             Ick.
#
#                                           ReviewText  Helpfulness
# 0  Text: Since this seems to be a main concern, I...           66
# 1  Text: I couldn't get my dog to take her incont...            0
# 2  Text: I appreciate that Gloria Jeans is availa...          100
# 3  Text: I bought this on special, thought it wou...            0
# 4  Text: This is my very first review - I thought...           62

# %% [markdown]
# #Removig the Score which is equal to 3

# %%
df_data1=df_data1[df_data1['Score']!=3]

# %% [markdown]
# #Splittig the data ito Train and Test

# %%
from pandas.core.common import random_state
X=df_data1[['ReviewText']]
y=df_data1[['Score']]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=40)

# %% [markdown]
# #Data cleaning and Data Transformations on Train data

# %%
import nltk
nltk.download('omw-1.4')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

## initialise the inbuilt Stemmer
stemmer = PorterStemmer()

## We can also use Lemmatizer instead of Stemmer
lemmatizer = WordNetLemmatizer()

# %%
def preprocess(raw_text, flag):
    # Removing special characters and digits
    sentence = re.sub("[^a-zA-Z]", " ", raw_text)
    
    # change sentence to lower case
    sentence = sentence.lower()

    # tokenize into words
    tokens = sentence.split()
    
    # remove stop words                
    clean_tokens = [t for t in tokens if not t in stopwords.words("english")]
    
    # Stemming/Lemmatization
    if(flag == 'stem'):
        clean_tokens = [stemmer.stem(word) for word in clean_tokens]
    else:
        clean_tokens = [lemmatizer.lemmatize(word) for word in clean_tokens]
    
    return pd.Series([" ".join(clean_tokens), len(clean_tokens)])

# %%
from tqdm import tqdm,tqdm_notebook

# %%
tqdm.pandas()

# %%
temp_df= X_train['ReviewText'].progress_apply(lambda x: preprocess(x, 'lemma'))
temp_df.columns = ['clean_text_lemma', 'text_length_lemma']
temp_df.head()
# Out:
# 100%|██████████| 394169/394169 [42:01<00:00, 156.35it/s]
#                                          clean_text_lemma  text_length_lemma
# 487577  text love mustard truly delicious dijon right ...                  9
# 112427  text recurring mole problem lost count many ye...                248
# 415296  text great product price use make graham crack...                 15
# 32696   text overall delicious really flavorful dressi...                 16
# 34236   text although much flavorful pomegranate green...                 40

# %%
ltempdf=temp_df.to_csv('X_train_Review_Text_0')

# %%
X_train=pd.read_csv('/content/drive/MyDrive/X_train_Review_Text_0')
X_train.drop(X_train.filter(regex="Unnamed"),axis=1, inplace=True)
X_train.head()
# Out:
#                                     clean_text_lemma  text_length_lemma
# 0  text love mustard truly delicious dijon right ...                  9
# 1  text recurring mole problem lost count many ye...                248
# 2  text great product price use make graham crack...                 15
# 3  text overall delicious really flavorful dressi...                 16
# 4  text although much flavorful pomegranate green...                 40

# %%
temp_df1= X_test['ReviewText'].progress_apply(lambda x: preprocess(x, 'lemma'))
temp_df1.columns = ['clean_text_lemma', 'text_length_lemma']
temp_df1.head()
# Out:
# 100%|██████████| 131390/131390 [13:58<00:00, 156.66it/s]
#                                          clean_text_lemma  text_length_lemma
# 281633  text bought peppercorn make asian dan dan nood...                 24
# 195856  text satisfied product arrived time expected i...                 10
# 434994  text popchips chili lime potato crunchy potato...                124
# 285472  text purchased honey jar give wedding favor ja...                 24
# 422482  text knew simple word could mean much one howe...                 81

# %%
temp_df1.to_csv('X_test_Review_Text_0')

# %%
X_test=pd.read_csv('/content/drive/MyDrive/X_test_Review_Text_0')
X_test.drop(X_test.filter(regex="Unnamed"),axis=1, inplace=True)
X_test.head()
# Out:
#                                     clean_text_lemma  text_length_lemma
# 0  text bought peppercorn make asian dan dan nood...                 24
# 1  text satisfied product arrived time expected i...                 10
# 2  text popchips chili lime potato crunchy potato...                124
# 3  text purchased honey jar give wedding favor ja...                 24
# 4  text knew simple word could mean much one howe...                 81

# %%
from sklearn.feature_extraction.text import CountVectorizer

vocab = CountVectorizer()

X_train_bow = vocab.fit_transform(X_train['clean_text_lemma'])

# %%
X_train_bow
# Out:
# <394169x87012 sparse matrix of type '<class 'numpy.int64'>'
# 	with 13225124 stored elements in Compressed Sparse Row format>

# %%
print("Total unique words:", len(vocab.vocabulary_))

print("Type of train features:", type(X_train_bow))

print("Shape of input data:", X_train_bow.shape)
# Out:
# Total unique words: 87012
# Type of train features: <class 'scipy.sparse._csr.csr_matrix'>
# Shape of input data: (394169, 87012)

# %%
X_test_bow = vocab.transform(X_test['clean_text_lemma'])

# %%
print("Total unique words:", len(vocab.vocabulary_))

print("Type of train features:", type(X_test_bow))

print("Shape of input data:", X_test_bow.shape)
# Out:
# Total unique words: 87012
# Type of train features: <class 'scipy.sparse._csr.csr_matrix'>
# Shape of input data: (131390, 87012)

# %% [markdown]
# #Model Building

# %% [markdown]
# ##Logistic Regression

# %%
Algorithm=[]
Accuracy_score=[]
Precision_score=[]
Confusion_matrix=[]
F1_score=[]
Roc_Auc_Score=[]
Log_Los=[]

# %%
from sklearn.linear_model import LogisticRegression
regressor = LogisticRegression()
regressor.fit(X_train_bow, y_train)
y_test_pred = regressor.predict(X_test_bow)
from sklearn import metrics
a=metrics.accuracy_score(y_test,y_test_pred)
Algorithm.append("LogisticRegression")
Accuracy_score.append(a)
Precision_score.append(metrics.precision_score(y_test,y_test_pred))
Confusion_matrix.append(metrics.confusion_matrix(y_test,y_test_pred))
F1_score.append(metrics.f1_score(y_test,y_test_pred))
Roc_Auc_Score.append(metrics.roc_auc_score(y_test,y_test_pred))
Log_Los.append(metrics.log_loss(y_test,y_test_pred))
print(a)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.9344546769160514

# %% [markdown]
# ##KNN classification

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN_classification=KNeighborsClassifier()
KNN_classification.fit(X_train_bow,y_train)
y_test_pred=KNN_classification.predict(X_test_bow)
from sklearn import metrics
a=metrics.accuracy_score(y_test,y_test_pred)
Algorithm.append("KNeighborsClassifier")
Accuracy_score.append(a)
Precision_score.append(metrics.precision_score(y_test,y_test_pred))
Confusion_matrix.append(metrics.confusion_matrix(y_test,y_test_pred))
F1_score.append(metrics.f1_score(y_test,y_test_pred))
Roc_Auc_Score.append(metrics.roc_auc_score(y_test,y_test_pred))
Log_Los.append(metrics.log_loss(y_test,y_test_pred))
print(a)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 0.8825481391277875

# %% [markdown]
# ##Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
DT_classification=DecisionTreeClassifier()
DT_classification.fit(X_train_bow,y_train)
y_test_pred=DT_classification.predict(X_test_bow)
from sklearn import metrics
a=metrics.accuracy_score(y_test,y_test_pred)
Algorithm.append("DecisionTreeClassifier")
Accuracy_score.append(a)
Precision_score.append(metrics.precision_score(y_test,y_test_pred))
Confusion_matrix.append(metrics.confusion_matrix(y_test,y_test_pred))
F1_score.append(metrics.f1_score(y_test,y_test_pred))
Roc_Auc_Score.append(metrics.roc_auc_score(y_test,y_test_pred))
Log_Los.append(metrics.log_loss(y_test,y_test_pred))
print(a)
# Out:
# 0.911248953497222

# %% [markdown]
# ## Ensemble
#  ## Training-Random Forest classification

# %%
from sklearn.ensemble import RandomForestClassifier
Random_classification=RandomForestClassifier()
Random_classification.fit(X_train_bow,y_train)
y_test_pred=Random_classification.predict(X_test_bow)
from sklearn import metrics
a=metrics.accuracy_score(y_test,y_test_pred)
Algorithm.append("RandomForestClassifier")
Accuracy_score.append(a)
Precision_score.append(metrics.precision_score(y_test,y_test_pred))
Confusion_matrix.append(metrics.confusion_matrix(y_test,y_test_pred))
F1_score.append(metrics.f1_score(y_test,y_test_pred))
Roc_Auc_Score.append(metrics.roc_auc_score(y_test,y_test_pred))
Log_Los.append(metrics.log_loss(y_test,y_test_pred))
print(a)
# Out:
# <ipython-input-69-662ec2e7b094>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   Random_classification.fit(X_train_bow,y_train)
# 0.927680949843976

# %% [markdown]
# ## Training-Adaboost Classification

# %%
from sklearn.ensemble import AdaBoostClassifier
ADA_classification=AdaBoostClassifier()
ADA_classification.fit(X_train_bow,y_train)
y_test_pred=ADA_classification.predict(X_test_bow)
from sklearn import metrics
a=metrics.accuracy_score(y_test,y_test_pred)
Algorithm.append("AdaBoostClassifier")
Accuracy_score.append(a)
Precision_score.append(metrics.precision_score(y_test,y_test_pred))
Confusion_matrix.append(metrics.confusion_matrix(y_test,y_test_pred))
F1_score.append(metrics.f1_score(y_test,y_test_pred))
Roc_Auc_Score.append(metrics.roc_auc_score(y_test,y_test_pred))
Log_Los.append(metrics.log_loss(y_test,y_test_pred))
print(a)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.879458101834234

# %%
def add_value_labels(ax, spacing=5):
    """Add labels to the end of each bar in a bar chart.

    Arguments:
        ax (matplotlib.axes.Axes): The matplotlib object containing the axes
            of the plot to annotate.
        spacing (int): The distance between the labels and the bars.
    """

    # For each bar: Place a label
    for rect in ax.patches:
        # Get X and Y placement of label from rect.
        y_value = rect.get_height()
        x_value =rect.get_x() + rect.get_width() / 2
        # Number of points between bar and label. Change to your liking.
        space = spacing
        # Vertical alignment for positive values
        va = 'bottom'

        # If value of bar is negative: Place label below bar
        if y_value < 0:
            # Invert space to place label below
            space *= -1
            # Vertically align label at top
            va = 'top'
            
        # Use Y value as label and format number with one decimal place
        label = "{:.3f}".format(y_value)

        # Create annotation
        ax.annotate(
            label,                      # Use `label` as label
            (x_value, y_value),         # Place label at end of the bar
            xytext=(0, space),          # Vertically shift label by `space`
            textcoords="offset points", # Interpret `xytext` as offset in points
            ha='center',                # Horizontally center label
            va=va)                      # Vertically align label differently for
                                        # positive and negative values.

# %%
overview=pd.DataFrame({"Accuracy_score":Accuracy_score,"Precision_score":Precision_score,
                      "F1_score":F1_score,"Roc_Auc_Score":Roc_Auc_Score},index=Algorithm)

# %%
overview
# Out:
#                         Accuracy_score  Precision_score  F1_score  \
# LogisticRegression            0.934455         0.948379  0.961743
# KNeighborsClassifier          0.882548         0.894366  0.933510
# DecisionTreeClassifier        0.911249         0.943679  0.947681
# RandomForestClassifier        0.927689         0.922374  0.958885
# RandomForestClassifier        0.927681         0.922275  0.958885
# AdaBoostClassifier            0.879458         0.893998  0.931642
#
#                         Roc_Auc_Score
# LogisticRegression           0.843488
# KNeighborsClassifier         0.674853
# DecisionTreeClassifier       0.821539
# RandomForestClassifier       0.770919
# RandomForestClassifier       0.770635
# AdaBoostClassifier           0.672984

# %%
fig,axes=plt.subplots(figsize=(15,7),dpi=90)
ax=overview.T.plot(ax=axes,kind='bar',width=0.8,align='center',alpha=1.0,color=['#C94845', '#4958B5', '#49D845', '#777777','#FA08A5'],edgecolor='black')
add_value_labels(ax)
ax.set_xlabel("Algorithm's",fontsize=25,fontweight='bold',color='palevioletred')
ax.set_ylabel("Score",fontsize=20,fontweight='bold',color='darkgoldenrod')
plt.xticks(rotation=90,fontsize='large')
plt.legend(bbox_to_anchor=(1,1))
plt.xticks(fontsize=12);

# %%
plt.figure(figsize=(15,7),dpi=90)
ax=sns.barplot(x=overview.index,y='Accuracy_score',data=overview,palette='viridis',edgecolor='red')
add_value_labels(ax)
ax.set_xlabel('Algorithm',fontsize=25,fontweight='bold',color='palevioletred')
ax.set_ylabel('Accuracy_score',fontsize=20,fontweight='bold',color='darkgoldenrod')
plt.xticks(rotation=90,fontsize='large')
plt.xlabel('Algorithm')
plt.show()

# %% [markdown]
# # Conclusion

# %%
df_data1
# Out:
#         Score       Time                              ReviewSummary  \
# 0           1 2008-05-16                              Great Tasting
# 1           1 2009-12-08                             Unbelieveable!
# 2           1 2010-03-04             Nice flavor and good packaging
# 3           1 2011-09-12                                  On the Go
# 4           0 2008-01-24                                       Ick.
# ...       ...        ...                                        ...
# 568168      1 2012-03-03   Good alternative to higher caloric chips
# 568169      1 2008-04-05                     Great Service, Great T
# 568170      1 2012-08-01      Great product...close to S'bux Sidamo
# 568171      1 2012-08-23                         HIMALAYAN SEA SALT
# 568172      1 2012-09-15                          Ghost Pepper salt
#
#                                                ReviewText  Helpfulness
# 0       Text: Since this seems to be a main concern, I...           66
# 1       Text: I couldn't get my dog to take her incont...            0
# 2       Text: I appreciate that Gloria Jeans is availa...          100
# 3       Text: I bought this on special, thought it wou...            0
# 4       Text: This is my very first review - I thought...           62
# ...                                                   ...          ...
# 568168  Text: Saw these chips on Dr. Oz as an alternat...            0
# 568169  Text: Yes , Amazon really does try to provide ...          100
# 568170  Text: Lovely coffee.  Smooth, not too jittery....            0
# 568171  Text: The Spice Lab is a completely wonderful ...            0
# 568172  Text: Fresh taste with the flavor of the peppe...            0
#
# [525559 rows x 5 columns]

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import re
import seaborn as sns

# %%
df_data1=pd.read_csv('/content/drive/MyDrive/Cleaned_Data1')
df_data1.drop(df_data1.filter(regex="Unnamed"),axis=1, inplace=True)

# %%
df_data1["Sentiment"] = df_data1["Score"].apply(lambda score: "positive" if score >= 3 else ("negative" if score < 3 else "not defined"))

# %%
plt.figure(figsize=(15,15),dpi=100)
ax = df_data1['Score'].value_counts().sort_index() .plot(kind='bar',figsize=(15, 6),color='palevioletred')
ax.set_xlabel('Review Stars',fontsize=15,fontweight='bold',color='maroon')
ax.set_title('Count of Reviews by Score',fontsize=25,fontweight='bold',color='olive')
add_value_labels(ax)
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(10,7),dpi=100)
ax=sns.countplot(x='Sentiment', order=["positive", "negative"], data=df_data1,palette='magma')
ax.set_xlabel('Sentiment',fontsize=15,fontweight='bold',color='red')
plt.xlabel('Sentiment')
add_value_labels(ax)
plt.show()

# %%
df_data1["Usefulness"] = (df_data1['Helpfulness']).apply(lambda n: ">75%" if n > 75 else ("<25%" if n <25 else ("25-75%" if n >= 25 and n <= 75 else "useless")))

# %%
plt.figure(figsize=(10,7),dpi=100)
ax=sns.countplot(x='Usefulness', order=['useless', '>75%', '25-75%', '<25%'], data=df_data1,palette="viridis")
ax.set_xlabel('Usefulness',fontsize=15,fontweight='bold',color='crimson')
plt.xlabel('Usefulness')
add_value_labels(ax)
plt.show()

# %%
plt.figure(figsize=(10,7),dpi=100)
ax=sns.countplot(x='Sentiment', hue='Usefulness', order=["positive", "negative"],hue_order=['>75%', '25-75%', '<25%'], data=df_data1,palette='cubehelix')
ax.set_xlabel('Sentiment',fontsize=15,fontweight='bold',color='darkgoldenrod')
plt.xlabel('Sentiment')
add_value_labels(ax)
plt.show()

# %%
fig,axes=plt.subplots(1,2,figsize=(15,5),dpi=100)
df_data1['Sentiment'].value_counts()[0:5].plot(kind='pie',ax=axes[0],ylabel=' ',autopct='%.2f',shadow=True)
axes[0].title.set_text('Sentiment')
df_data1['ReviewSummary'].value_counts()[0:5].plot(kind='pie',ax=axes[1],ylabel=' ',autopct='%.2f',shadow=True)
axes[1].title.set_text('ReviewSummary')

# %%
pos = df_data1.loc[df_data1['Sentiment'] == 'positive']
pos = pos[0:50]

neg = df_data1.loc[df_data1['Sentiment'] == 'negative']
neg = neg[0:50]

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud
import string
import matplotlib.pyplot as plt


def create_Word_Corpus(temp):
    words_corpus = ''
    for val in df_data1["ReviewSummary"]:
        text1 = str(val).lower()
        tokens = []
        tokens = word_tokenize(text1)
        tokens = [word for word in tokens if word not in stopwords.words('english')]
        for words in tokens:
            words_corpus = words_corpus + ' ' + words
    return words_corpus
# Generate a word cloud image
pos_wordcloud = WordCloud(width=900, height=500).generate(create_Word_Corpus(pos))
neg_wordcloud = WordCloud(width=900, height=500).generate(create_Word_Corpus(neg))

# %%
# Plot cloud
def plot_Cloud(wordCloud):
    plt.figure( figsize=(20,10), facecolor='w')
    plt.imshow(wordCloud)
    plt.axis("off")
    plt.tight_layout(pad=0)
    plt.show()
    plt.savefig('wordclouds.png', facecolor='w', bbox_inches='tight')

# %%
#Visuallizing popular positive words
plot_Cloud(pos_wordcloud)

# %%
#Visuallizing popular negative words
plot_Cloud(neg_wordcloud)

# %%
df_data1.head()
# Out:
#    Score        Time                    ReviewSummary  \
# 0      4  1210896000                    Great Tasting
# 1      5  1260230400                   Unbelieveable!
# 2      5  1267660800   Nice flavor and good packaging
# 3      4  1315785600                        On the Go
# 4      1  1201132800                             Ick.
#
#                                           ReviewText  Helpfulness Sentiment  \
# 0  Text: Since this seems to be a main concern, I...           66  positive
# 1  Text: I couldn't get my dog to take her incont...            0  positive
# 2  Text: I appreciate that Gloria Jeans is availa...          100  positive
# 3  Text: I bought this on special, thought it wou...            0  positive
# 4  Text: This is my very first review - I thought...           62  negative
#
#   Usefulness
# 0     25-75%
# 1       <25%
# 2       >75%
# 3       <25%
# 4     25-75%

# %%
num=df_data.select_dtypes(include='number')
cat=df_data.select_dtypes(exclude='number').drop(['ProductId','UserId','ProfileName','Time'],axis=1)

# %%
cat.head()
# Out:
#         HelpfulnessNumerator       HelpfulnessDenominator       Score  \
# 0  HelpfulnessNumerator: 2\n  HelpfulnessDenominator: 3\n  Score: 4\n
# 1  HelpfulnessNumerator: 0\n  HelpfulnessDenominator: 0\n  Score: 5\n
# 2  HelpfulnessNumerator: 1\n  HelpfulnessDenominator: 1\n  Score: 5\n
# 3  HelpfulnessNumerator: 0\n  HelpfulnessDenominator: 0\n  Score: 4\n
# 4  HelpfulnessNumerator: 5\n  HelpfulnessDenominator: 8\n  Score: 1\n
#
#                                      ReviewSummary  \
# 0                   ReviewSummary: Great Tasting\n
# 1                  ReviewSummary: Unbelieveable!\n
# 2  ReviewSummary: Nice flavor and good packaging\n
# 3                       ReviewSummary: On the Go\n
# 4                            ReviewSummary: Ick.\n
#
#                                           ReviewText
# 0  ReviewText: Since this seems to be a main conc...
# 1  ReviewText: I couldn't get my dog to take her ...
# 2  ReviewText: I appreciate that Gloria Jeans is ...
# 3  ReviewText: I bought this on special, thought ...
# 4  ReviewText: This is my very first review - I t...

# %%
num.head()
# Out:
#    Unnamed: 0
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4

# %%
fig,axes=plt.subplots(1,2,figsize=(15,6),dpi=100)
sns.scatterplot(x=df_data['HelpfulnessNumerator'],y=df_data['Score'],data=df_data,ax=axes[0])
sns.scatterplot(x=df_data['Helpfulness'],y=df_data['Score'],data=df_data,ax=axes[1])
plt.show()

# %%
fig,axes=plt.subplots(1,2,figsize=(15,6),dpi=100)
sns.violinplot(x=df_data1['Sentiment'],y=df_data1['Score'],data=df_data1,ax=axes[0])
sns.violinplot(x=df_data1['Sentiment'],y=df_data1['Helpfulness'],data=df_data1)
plt.sca(axes[0])
plt.xticks(rotation=90)
plt.sca(axes[1])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,7),dpi=100)
sns.heatmap(df_data.corr(),annot=True,cmap=sns.cubehelix_palette(as_cmap=True))
plt.show()
# Out:
# <ipython-input-60-d3e82f80f725>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_data.corr(),annot=True,cmap=sns.cubehelix_palette(as_cmap=True))

# %%
plt.figure(figsize=(30,10),dpi=200)
sns.pairplot(data=df_data1[0:150000],hue='Sentiment',markers=["o", "s"])
plt.show()
